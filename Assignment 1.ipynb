# %% [markdown]
# ## Aim: Perform the following operations using Python on the Facebook metrics data sets a. Create data subsetsb. Merge Data c. Sort Data d. Transposing Data e. Shape and reshape Data

# %%
import pandas as pd
A=pd.read_csv("C:\\Users\\sahil\\OneDrive\\Desktop\\dataset_Facebook.csv")

# %% [markdown]
# ## Basic Operations

# %%
A.shape
# Out:
# (500, 19)

# %%
A.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
A.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# ## create subset

# %%
ss1 = A[['Type','Category','Post Month']]
ss1
# Out:
#        Type  Category  Post Month
# 0     Photo         2          12
# 1    Status         2          12
# 2     Photo         3          12
# 3     Photo         2          12
# 4     Photo         2          12
# ..      ...       ...         ...
# 495   Photo         3           1
# 496   Photo         2           1
# 497   Photo         1           1
# 498   Photo         3           1
# 499   Photo         2           1
#
# [500 rows x 3 columns]

# %%
ss1.shape
# Out:
# (500, 3)

# %%
ss2 = A.loc[201:500]
ss2.shape
# Out:
# (299, 19)

# %%
ss3 = A.loc[0:200]
ss3.shape
# Out:
# (201, 19)

# %%
ss4 = A.loc[0:2,['Type','Post Month']]
ss4
# Out:
#      Type  Post Month
# 0   Photo          12
# 1  Status          12
# 2   Photo          12

# %%
ss4.shape
# Out:
# (3, 2)

# %% [markdown]
# ## Merge the subsets by row

# %%
m1 = pd.concat([ss2,ss3])
m1.shape
# Out:
# (500, 19)

# %%
m2 = pd.concat([ss2,ss4])
m2.shape
# Out:
# (302, 19)

# %% [markdown]
# ## Merge the subsets by columns

# %%
m3 = ss1.merge(ss2,on ='Type')
m3.shape
# Out:
# (114830, 21)

# %%
sb1 = A[["Post Month","Type"]]
sb1.shape
# Out:
# (500, 2)

# %%
sb2 = A[["Category","Type"]]
sb2.shape
# Out:
# (500, 2)

# %%
m4 = sb1.merge(sb2,left_index = True, right_index = True)
m4.shape
# Out:
# (500, 4)

# %% [markdown]
# ## sort the subset

# %%
st = A.sort_values(by="Type")
st
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195   Link         2           3             6          6
# 470             91437   Link         1           2             3         13
# 41             138895   Link         1          12             6          3
# 43             138353   Link         1          12             5          3
# 45             138353   Link         1          12             4          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 55             138329  Video         1          11             6          2
# 277            126424  Video         1           6             2         13
# 243            130791  Video         1           7             3         11
# 74             137893  Video         1          11             3         11
#
# ...

# %% [markdown]
# ## sort the dataframe based on multiple columns

# %%
st1 = A.sort_values(by=['Type','Post Month'])
st1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 477             86909   Link         1           1             6          4
# 481             86491   Link         1           1             4          4
# 485             86491   Link         1           1             2          2
# 492             85979   Link         1           1             5         11
# 470             91437   Link         1           2             3         13
# ..                ...    ...       ...         ...           ...        ...
# 183            134879  Video         1           9             2         10
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 29             138895  Video         1          12             4         11
#
# ...

# %%
st2 = A.sort_values(by='Post Weekday', ascending = False)
st2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 250            129600   Photo         1           7             7          6
# 428            100732   Photo         1           3             7         15
# 430            100732    Link         1           3             7         14
# 431            100732   Photo         1           3             7         12
# 380            111620   Photo         1           4             7         14
# ..                ...     ...       ...         ...           ...        ...
# 220            131956   Photo         2           8             1          4
# 219            131956   Photo         3           8             1         12
# 106            137020   Photo         3          10             1         11
# 107            136736  Status         2          10             1          4
# 262            128032   Photo         2           7             1          3
#
# ...

# %% [markdown]
# ## Transpose the dataset

# %%
tp = A.transpose()
tp.shape
# Out:
# (19, 500)

# %% [markdown]
# ## Reshape the data

# %%
rs = pd.melt(A, id_vars = ['Type'],value_vars = ['Post Month'], var_name =['Post'])
rs
# Out:
#        Type        Post  value
# 0     Photo  Post Month     12
# 1    Status  Post Month     12
# 2     Photo  Post Month     12
# 3     Photo  Post Month     12
# 4     Photo  Post Month     12
# ..      ...         ...    ...
# 495   Photo  Post Month      1
# 496   Photo  Post Month      1
# 497   Photo  Post Month      1
# 498   Photo  Post Month      1
# 499   Photo  Post Month      1
#
# [500 rows x 3 columns]

# %%
rs1 = pd.melt(A, id_vars = ['Type'],value_vars = ['Post Month','Category'])
rs1
# Out:
#        Type    variable  value
# 0     Photo  Post Month     12
# 1    Status  Post Month     12
# 2     Photo  Post Month     12
# 3     Photo  Post Month     12
# 4     Photo  Post Month     12
# ..      ...         ...    ...
# 995   Photo    Category      3
# 996   Photo    Category      2
# 997   Photo    Category      1
# 998   Photo    Category      3
# 999   Photo    Category      2
#
# [1000 rows x 3 columns]
